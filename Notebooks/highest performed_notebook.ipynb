# %%
import pandas as pd
train = pd.read_csv('train.csv')

# %%
train.head()
# Out:
#    id  Time_spent_Alone Stage_fear  Social_event_attendance  Going_outside  \
# 0   0               0.0         No                      6.0            4.0
# 1   1               1.0         No                      7.0            3.0
# 2   2               6.0        Yes                      1.0            0.0
# 3   3               3.0         No                      7.0            3.0
# 4   4               1.0         No                      4.0            4.0
#
#   Drained_after_socializing  Friends_circle_size  Post_frequency Personality
# 0                        No                 15.0             5.0   Extrovert
# 1                        No                 10.0             8.0   Extrovert
# 2                       NaN                  3.0             0.0   Introvert
# 3                        No                 11.0             5.0   Extrovert
# 4                        No                 13.0             NaN   Extrovert

# %%
train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 18524 entries, 0 to 18523
# Data columns (total 9 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   id                         18524 non-null  int64
#  1   Time_spent_Alone           17334 non-null  float64
#  2   Stage_fear                 16631 non-null  object
#  3   Social_event_attendance    17344 non-null  float64
#  4   Going_outside              17058 non-null  float64
#  5   Drained_after_socializing  17375 non-null  object
#  6   Friends_circle_size        17470 non-null  float64
#  7   Post_frequency             17260 non-null  float64
#  8   Personality                18524 non-null  object
# dtypes: float64(5), int64(1), object(3)
# memory usage: 1.3+ MB

# %%
time_spent_alone = train[train['Time_spent_Alone'].isna() == True]['id']

# %%
import numpy as np
time_spent_alone = np.array(time_spent_alone)

# %%
time_spent_alone
# Out:
# array([   15,    29,    31, ..., 18515, 18516, 18522], shape=(1190,))

# %%
train.iloc[time_spent_alone]['Time_spent_Alone'] = 'NONE'
# Out:
# C:\Users\kumar\AppData\Local\Temp\ipykernel_68988\4130637168.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   train.iloc[time_spent_alone]['Time_spent_Alone'] = 'NONE'

# %%
test = pd.read_csv('test.csv')

# %%
test
# Out:
#          id  Time_spent_Alone Stage_fear  Social_event_attendance  \
# 0     18524               3.0         No                      7.0
# 1     18525               NaN        Yes                      0.0
# 2     18526               3.0         No                      5.0
# 3     18527               3.0         No                      4.0
# 4     18528               9.0        Yes                      1.0
# ...     ...               ...        ...                      ...
# 6170  24694               3.0         No                      5.0
# 6171  24695               8.0        Yes                      2.0
# 6172  24696               2.0         No                      4.0
# 6173  24697               3.0         No                      4.0
# 6174  24698               NaN        Yes                      1.0
#
#       Going_outside Drained_after_socializing  Friends_circle_size  \
# 0               4.0                        No                  6.0
# ...

# %%
test.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6175 entries, 0 to 6174
# Data columns (total 8 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   id                         6175 non-null   int64
#  1   Time_spent_Alone           5750 non-null   float64
#  2   Stage_fear                 5577 non-null   object
#  3   Social_event_attendance    5778 non-null   float64
#  4   Going_outside              5709 non-null   float64
#  5   Drained_after_socializing  5743 non-null   object
#  6   Friends_circle_size        5825 non-null   float64
#  7   Post_frequency             5767 non-null   float64
# dtypes: float64(5), int64(1), object(2)
# memory usage: 386.1+ KB

# %%
test.describe()
# Out:
#                  id  Time_spent_Alone  Social_event_attendance  Going_outside  \
# count   6175.000000       5750.000000              5778.000000    5709.000000
# mean   21611.000000          3.116870                 5.287989       4.037835
# std     1782.713288          2.985658                 2.758052       2.045207
# min    18524.000000          0.000000                 0.000000       0.000000
# 25%    20067.500000          1.000000                 3.000000       3.000000
# 50%    21611.000000          2.000000                 5.000000       4.000000
# 75%    23154.500000          4.000000                 8.000000       6.000000
# max    24698.000000         11.000000                10.000000       7.000000
#
#        Friends_circle_size  Post_frequency
# count          5825.000000     5767.000000
# mean              8.008412        5.028958
# std               4.192701        2.867285
# min               0.000000        0.000000
# 25%               5.000000        3.000000
# ...

# %%
train.iloc[time_spent_alone]
# Out:
#           id  Time_spent_Alone Stage_fear  Social_event_attendance  \
# 15        15               NaN         No                      7.0
# 29        29               NaN        Yes                      1.0
# 31        31               NaN         No                      4.0
# 41        41               NaN         No                      6.0
# 62        62               NaN         No                      6.0
# ...      ...               ...        ...                      ...
# 18502  18502               NaN         No                      4.0
# 18510  18510               NaN         No                      NaN
# 18515  18515               NaN         No                      9.0
# 18516  18516               NaN         No                      6.0
# 18522  18522               NaN        Yes                      1.0
#
#        Going_outside Drained_after_socializing  Friends_circle_size  \
# 15               6.0                        No                  5.0
# ...

# %%
time_spent_alone_null_df = train['Time_spent_Alone'].dropna().copy()

# %%
median_time_spent_alone = time_spent_alone_null_df.median()

# %%
time_spent_alone_null_df.info()
# Out:
# <class 'pandas.core.series.Series'>
# Index: 17334 entries, 0 to 18523
# Series name: Time_spent_Alone
# Non-Null Count  Dtype
# --------------  -----
# 17334 non-null  float64
# dtypes: float64(1)
# memory usage: 270.8 KB

# %%
train['Time_spent_Alone'] = train['Time_spent_Alone'].fillna(median_time_spent_alone) # inplace in this argument has been deprecated

# %%
train['Time_spent_Alone']
# Out:
# 0        0.0
# 1        1.0
# 2        6.0
# 3        3.0
# 4        1.0
#         ...
# 18519    3.0
# 18520    1.0
# 18521    7.0
# 18522    2.0
# 18523    1.0
# Name: Time_spent_Alone, Length: 18524, dtype: float64

# %%
train['Stage_fear'] = train['Stage_fear'].fillna('Unknown')

# %%
social_attendance = train['Social_event_attendance'].dropna().copy()

# %%
median_social_attendance = social_attendance.median()

# %%
train['Social_event_attendance'] = train['Social_event_attendance'].fillna(median_social_attendance)

# %%
train['Social_event_attendance'].info()
# Out:
# <class 'pandas.core.series.Series'>
# RangeIndex: 18524 entries, 0 to 18523
# Series name: Social_event_attendance
# Non-Null Count  Dtype
# --------------  -----
# 18524 non-null  float64
# dtypes: float64(1)
# memory usage: 144.8 KB

# %%
going_outside = train['Going_outside'].dropna().copy()

# %%
median_going_outside = going_outside.median()

# %%
train['Going_outside'] = train['Going_outside'].fillna(median_going_outside)

# %%
train['Drained_after_socializing'] = train['Drained_after_socializing'].fillna('Unknown')

# %%
friend_circle_size = train['Friends_circle_size'].dropna().copy()

# %%
median_friend_circle_size = friend_circle_size.median()

# %%
train['Friends_circle_size'] = train['Friends_circle_size'].fillna(median_friend_circle_size)

# %%
post_frequency = train['Post_frequency'].dropna().copy()

# %%
median_post_frequency = post_frequency.median()

# %%
train['Post_frequency'] = train['Post_frequency'].fillna(median_post_frequency)

# %%
train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 18524 entries, 0 to 18523
# Data columns (total 9 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   id                         18524 non-null  int64
#  1   Time_spent_Alone           18524 non-null  float64
#  2   Stage_fear                 18524 non-null  object
#  3   Social_event_attendance    18524 non-null  float64
#  4   Going_outside              18524 non-null  float64
#  5   Drained_after_socializing  18524 non-null  object
#  6   Friends_circle_size        18524 non-null  float64
#  7   Post_frequency             18524 non-null  float64
#  8   Personality                18524 non-null  object
# dtypes: float64(5), int64(1), object(3)
# memory usage: 1.3+ MB

# %%
train.describe()
# Out:
#                  id  Time_spent_Alone  Social_event_attendance  Going_outside  \
# count  18524.000000      18524.000000             18524.000000   18524.000000
# mean    9261.500000          3.064673                 5.248219       4.040812
# std     5347.562529          2.919057                 2.665002       1.979312
# min        0.000000          0.000000                 0.000000       0.000000
# 25%     4630.750000          1.000000                 3.000000       3.000000
# 50%     9261.500000          2.000000                 5.000000       4.000000
# 75%    13892.250000          4.000000                 7.000000       6.000000
# max    18523.000000         11.000000                10.000000       7.000000
#
#        Friends_circle_size  Post_frequency
# count         18524.000000    18524.000000
# mean              7.996923        4.983319
# std               4.101561        2.779172
# min               0.000000        0.000000
# 25%               5.000000        3.000000
# ...

# %%
train.head()
# Out:
#    id  Time_spent_Alone Stage_fear  Social_event_attendance  Going_outside  \
# 0   0               0.0         No                      6.0            4.0
# 1   1               1.0         No                      7.0            3.0
# 2   2               6.0        Yes                      1.0            0.0
# 3   3               3.0         No                      7.0            3.0
# 4   4               1.0         No                      4.0            4.0
#
#   Drained_after_socializing  Friends_circle_size  Post_frequency Personality
# 0                        No                 15.0             5.0   Extrovert
# 1                        No                 10.0             8.0   Extrovert
# 2                   Unknown                  3.0             0.0   Introvert
# 3                        No                 11.0             5.0   Extrovert
# 4                        No                 13.0             5.0   Extrovert

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# %%
sns.countplot(x = 'Personality',hue = 'Time_spent_Alone', data = train)
plt.title('Time spent alone against Personality')
plt.xlabel('Personality')
plt.ylabel('Count of People')
plt.tight_layout()

# %%
sns.countplot(x = 'Personality',hue = 'Social_event_attendance', data = train)
plt.title('Social event attendance against Personality')
plt.xlabel('Personality')
plt.ylabel('Count of People')
plt.tight_layout()

# %%
sns.countplot(x = 'Personality',hue = 'Stage_fear', data = train)
plt.title('Stage fear against Personality')
plt.xlabel('Personality')
plt.ylabel('Count of People')
plt.tight_layout()

# %%
sns.countplot(x = 'Personality', hue = 'Going_outside', data = train)
plt.title('Going outside against Personality')
plt.xlabel('Personality')
plt.ylabel('Count of People')
plt.tight_layout()

# %%
sns.countplot(x = 'Personality', hue = 'Drained_after_socializing', data = train)
plt.title('Going outside against Personality')
plt.xlabel('Personality')
plt.ylabel('Count of People')
plt.tight_layout()

# %%
sns.countplot(x = 'Personality', hue = 'Friends_circle_size', data = train)
plt.title('Friends circle against Personality')
plt.xlabel('Personality')
plt.ylabel('Count of People')
plt.tight_layout()

# %%
sns.countplot(x = 'Personality', hue = 'Post_frequency', data = train)
plt.title('Post frequency against Personality')
plt.xlabel('Personality')
plt.ylabel('Count of People')
plt.tight_layout()

# %% [markdown]
# From the above analysis this is certainly clear that all the features are highly responsive and is likely to give good results when used in training of the model and will participate highly but among all of them the most promising ones are Stage_fear, Going_outside, Friends_circle_size, Social_event_attendance and Time_spent_alone

# %%
from sklearn.model_selection import StratifiedShuffleSplit

# %%
sss = StratifiedShuffleSplit(n_splits =1, test_size = 0.2, random_state = 42)

for train_index,test_index in sss.split(train,train['Personality']):
    X_train = train.iloc[train_index].copy()
    X_test = train.iloc[test_index].copy()

# %%
from sklearn.preprocessing import OneHotEncoder

stage_fear = OneHotEncoder(drop = 'first', sparse_output = False)
drained_after_socializing = OneHotEncoder(drop = 'first', sparse_output = False)

encoded_stage_fear_train = stage_fear.fit_transform(X_train[['Stage_fear']])
encoded_stage_fear_test = stage_fear.transform(X_test[['Stage_fear']])
encoded_drained_train = drained_after_socializing.fit_transform(X_train[['Drained_after_socializing']])
encoded_drained_test = drained_after_socializing.transform(X_test[['Drained_after_socializing']])

sf_train_df = pd.DataFrame(encoded_stage_fear_train, columns = stage_fear.get_feature_names_out(['Stage_fear']), index = X_train.index)
sf_test_df = pd.DataFrame(encoded_stage_fear_test, columns = stage_fear.get_feature_names_out(['Stage_fear']), index = X_test.index)
das_train_df = pd.DataFrame(encoded_drained_train, columns = drained_after_socializing.get_feature_names_out(['Drained_after_socializing']), index = X_train.index)
das_test_df = pd.DataFrame(encoded_drained_test, columns = drained_after_socializing.get_feature_names_out(['Drained_after_socializing']), index = X_test.index)

# %%
X_train = pd.concat([X_train, sf_train_df, das_train_df], axis =1)

# %%
X_test = pd.concat([X_test, sf_test_df, das_test_df], axis =1)

# %%
X_train.head()
# Out:
#           id  Time_spent_Alone Stage_fear  Social_event_attendance  \
# 12652  12652               8.0        Yes                      0.0
# 5914    5914               3.0         No                      7.0
# 5169    5169               0.0    Unknown                      7.0
# 1501    1501               8.0    Unknown                      2.0
# 4788    4788               3.0         No                      7.0
#
#        Going_outside Drained_after_socializing  Friends_circle_size  \
# 12652            3.0                       Yes                  2.0
# 5914             7.0                        No                 11.0
# 5169             6.0                        No                 12.0
# 1501             1.0                       Yes                  3.0
# 4788             5.0                        No                 11.0
#
#        Post_frequency Personality  Stage_fear_Unknown  Stage_fear_Yes  \
# 12652             1.0   Introvert                 0.0             1.0
# ...

# %%
dropping_columns = ['id','Stage_fear','Drained_after_socializing','Personality']

log_train_X = X_train.drop(dropping_columns, axis=1).copy()
log_train_y = X_train['Personality']

log_test_X = X_test.drop(dropping_columns, axis=1).copy()
log_test_y = X_test['Personality']

# %%
from sklearn.preprocessing import StandardScaler

# %%
scale = StandardScaler()

log_train_X_scale = scale.fit_transform(log_train_X)
log_test_X_scale = scale.transform(log_test_X)

# %%
log_train_X_df = pd.DataFrame(log_train_X_scale, columns = log_train_X.columns, index = log_train_X.index)

# %%
log_test_X_df = pd.DataFrame(log_test_X_scale, columns =log_test_X.columns, index = log_test_X.index)

# %%
from sklearn.linear_model import LogisticRegression

# %%
lr = LogisticRegression(random_state = 42)

lr.fit(log_train_X_df, log_train_y)
pred_lr = lr.predict(log_test_X_df)

# %%
from sklearn.metrics import accuracy_score,confusion_matrix,classification_report, ConfusionMatrixDisplay

# %%
accuracy_score(log_test_y, pred_lr)
# Out:
# 0.9721997300944669

# %%
from sklearn.model_selection import cross_val_score

# %%
scores = cross_val_score(lr, log_train_X_df, log_train_y, cv=5, scoring='accuracy')
print("Cross-validation accuracy scores:", scores)
print("Mean score:", scores.mean())
# Out:
# Cross-validation accuracy scores: [0.97031039 0.97132254 0.96592443 0.96659919 0.96658792]
# Mean score: 0.9681488925720412

# %%
c_mat = confusion_matrix(log_test_y, pred_lr)
cp = ConfusionMatrixDisplay(confusion_matrix = c_mat, display_labels = lr.classes_)
cp.plot(cmap='Blues')
plt.title('LogisticRegression Confusion matrix')
# Out:
# Text(0.5, 1.0, 'LogisticRegression Confusion matrix')

# %%
import numpy as np
features = log_train_X_df.columns

# Get coefficients (importance scores)
coefficients = lr.coef_[0]  # For binary classification, this is a 1D array

# Create a DataFrame for plotting
importance_df = pd.DataFrame({
    'Feature': features,
    'Importance': coefficients
})

# Sort by absolute importance
importance_df['Abs_importance'] = np.abs(importance_df['Importance'])
importance_df.sort_values(by='Abs_importance', ascending=True, inplace=True)

# Plot
plt.figure(figsize=(10, 6))
plt.barh(importance_df['Feature'], importance_df['Importance'], color='skyblue')
plt.axvline(0, color='gray', linestyle='--')
plt.title('Feature Importance from Logistic Regression (coefficients)')
plt.xlabel('Coefficient Value')
plt.tight_layout()
plt.show()

# %% [markdown]
# Now lets test this on RandomForestClassifier and XGBClassifier and see how that goes linear Regression did give some good results

# %%
from sklearn.preprocessing import OneHotEncoder

stage_fear = OneHotEncoder(sparse_output = False)
drained_after_socializing = OneHotEncoder(sparse_output = False)

encoded_stage_fear_train = stage_fear.fit_transform(X_train[['Stage_fear']])
encoded_stage_fear_test = stage_fear.transform(X_test[['Stage_fear']])
encoded_drained_train = drained_after_socializing.fit_transform(X_train[['Drained_after_socializing']])
encoded_drained_test = drained_after_socializing.transform(X_test[['Drained_after_socializing']])

sf_train_df = pd.DataFrame(encoded_stage_fear_train, columns = stage_fear.get_feature_names_out(['Stage_fear']), index = X_train.index)
sf_test_df = pd.DataFrame(encoded_stage_fear_test, columns = stage_fear.get_feature_names_out(['Stage_fear']), index = X_test.index)
das_train_df = pd.DataFrame(encoded_drained_train, columns = drained_after_socializing.get_feature_names_out(['Drained_after_socializing']), index = X_train.index)
das_test_df = pd.DataFrame(encoded_drained_test, columns = drained_after_socializing.get_feature_names_out(['Drained_after_socializing']), index = X_test.index)

# %%
drop_columns = ['Stage_fear_Unknown','Stage_fear_Yes','Drained_after_socializing_Unknown','Drained_after_socializing_Yes']
X_train.drop(drop_columns,axis=1,inplace=True)
X_test.drop(drop_columns,axis=1,inplace=True)

# %%
X_train = pd.concat([X_train, sf_train_df, das_train_df], axis =1)
X_test = pd.concat([X_test, sf_test_df, das_test_df], axis =1)

# %%
rfc_train_X = X_train.drop(dropping_columns,axis=1).copy()
rfc_test_X = X_test.drop(dropping_columns,axis=1).copy()

rfc_train_y = X_train['Personality']
rfc_test_y = X_test['Personality']

# %%
from sklearn.ensemble import RandomForestClassifier

rfc = RandomForestClassifier(random_state = 42)
rfc.fit(rfc_train_X,rfc_train_y)

pred_rfc = rfc.predict(rfc_test_X)

print(f'Accuracy: {accuracy_score(rfc_test_y,pred_rfc)}')
# Out:
# Accuracy: 0.9681511470985156

# %%
print(f'Classification Report: \n{classification_report(rfc_test_y,pred_rfc)}')
# Out:
# Classification Report:
#               precision    recall  f1-score   support
#
#    Extrovert       0.98      0.98      0.98      2740
#    Introvert       0.93      0.95      0.94       965
#
#     accuracy                           0.97      3705
#    macro avg       0.96      0.96      0.96      3705
# weighted avg       0.97      0.97      0.97      3705

# %%
scores = cross_val_score(rfc, rfc_train_X, rfc_train_y, cv=5, scoring='accuracy')
print("Cross-validation accuracy scores:", scores)
print("Mean score:", scores.mean())
# Out:
# Cross-validation accuracy scores: [0.96558704 0.96693657 0.96356275 0.96390013 0.96152548]
# Mean score: 0.964302397130967

# %%
features = rfc_train_X.columns
importances = rfc.feature_importances_

fi_df = pd.DataFrame({
    'Features': features,
    'Importances': importances
}).sort_values(by = 'Importances', ascending = False)

plt.figure(figsize = (10,10))
sns.barplot(x = 'Importances', y= 'Features', data = fi_df)
plt.title('Feature Importance (RandomForestClassifier)')
plt.xlabel('Importances')
plt.ylabel('Features')
plt.tight_layout()
plt.show()

# %% [markdown]
# So stage fear unknown and drained after socializing unknown almost contribute nothing but lets not drop them yet

# %%
xgb_test_y = rfc_test_y.apply(lambda x: 0 if x == 'Introvert' else 1)
xgb_train_y = rfc_train_y.apply(lambda x:0 if x == 'Introvert' else 1)

# %%
from xgboost import XGBClassifier

xgb = XGBClassifier(random_state =42)

xgb.fit(rfc_train_X,xgb_train_y)
pred_xgb = xgb.predict(rfc_test_X)

print(f'Accuracy: {accuracy_score(xgb_test_y,pred_xgb)}')
# Out:
# Accuracy: 0.9711201079622133

# %%
scores = cross_val_score(xgb, rfc_train_X,xgb_train_y, cv = 5, scoring = 'accuracy')
print("Cross-validation accuracy scores:", scores)
print("Mean score:", scores.mean())
# Out:
# Cross-validation accuracy scores: [0.96794872 0.96862348 0.96592443 0.96491228 0.96658792]
# Mean score: 0.966799364906724

# %%
print('Classification Report \n',classification_report(xgb_test_y, pred_xgb))
# Out:
# Classification Report
#                precision    recall  f1-score   support
#
#            0       0.94      0.95      0.94       965
#            1       0.98      0.98      0.98      2740
#
#     accuracy                           0.97      3705
#    macro avg       0.96      0.96      0.96      3705
# weighted avg       0.97      0.97      0.97      3705

# %% [markdown]
# Now this is the best model so far since it has also improved the scores for introvert also so lets train the model on the complete train

# %%
train
# Out:
#           id  Time_spent_Alone Stage_fear  Social_event_attendance  \
# 0          0               0.0         No                      6.0
# 1          1               1.0         No                      7.0
# 2          2               6.0        Yes                      1.0
# 3          3               3.0         No                      7.0
# 4          4               1.0         No                      4.0
# ...      ...               ...        ...                      ...
# 18519  18519               3.0         No                      7.0
# 18520  18520               1.0    Unknown                      6.0
# 18521  18521               7.0        Yes                      1.0
# 18522  18522               2.0        Yes                      1.0
# 18523  18523               1.0         No                      8.0
#
#        Going_outside Drained_after_socializing  Friends_circle_size  \
# 0                4.0                        No                 15.0
# ...

# %%
test.head()
# Out:
#       id  Time_spent_Alone Stage_fear  Social_event_attendance  Going_outside  \
# 0  18524               3.0         No                      7.0            4.0
# 1  18525               NaN        Yes                      0.0            0.0
# 2  18526               3.0         No                      5.0            6.0
# 3  18527               3.0         No                      4.0            4.0
# 4  18528               9.0        Yes                      1.0            2.0
#
#   Drained_after_socializing  Friends_circle_size  Post_frequency
# 0                        No                  6.0             NaN
# 1                       Yes                  5.0             1.0
# 2                        No                 15.0             9.0
# 3                        No                  5.0             6.0
# 4                       Yes                  1.0             1.0

# %%
test['Time_spent_Alone'] = test['Time_spent_Alone'].fillna(test[test['Time_spent_Alone'].notna()]['Time_spent_Alone'].median())

# %%
test['Stage_fear'] = test['Stage_fear'].fillna('Unknown')
test['Social_event_attendance']=test['Social_event_attendance'].fillna(test[test['Social_event_attendance'].notna()]['Social_event_attendance'].median())
test['Going_outside']=test['Going_outside'].fillna(test[test['Going_outside'].notna()]['Going_outside'].median())
test['Drained_after_socializing']=test['Drained_after_socializing'].fillna('Unknown')
test['Friends_circle_size']=test['Friends_circle_size'].fillna(test[test['Friends_circle_size'].notna()]['Friends_circle_size'].median())
test['Post_frequency']=test['Post_frequency'].fillna(test[test['Post_frequency'].notna()]['Post_frequency'].median())

# %%
test.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6175 entries, 0 to 6174
# Data columns (total 8 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   id                         6175 non-null   int64
#  1   Time_spent_Alone           6175 non-null   float64
#  2   Stage_fear                 6175 non-null   object
#  3   Social_event_attendance    6175 non-null   float64
#  4   Going_outside              6175 non-null   float64
#  5   Drained_after_socializing  6175 non-null   object
#  6   Friends_circle_size        6175 non-null   float64
#  7   Post_frequency             6175 non-null   float64
# dtypes: float64(5), int64(1), object(2)
# memory usage: 386.1+ KB

# %%
stage_fear = OneHotEncoder(sparse_output = False)
drained_after_socializing = OneHotEncoder(sparse_output = False)

encoded_stage_fear_train = stage_fear.fit_transform(train[['Stage_fear']])
encoded_stage_fear_test = stage_fear.transform(test[['Stage_fear']])
encoded_drained_train = drained_after_socializing.fit_transform(train[['Drained_after_socializing']])
encoded_drained_test = drained_after_socializing.transform(test[['Drained_after_socializing']])

sf_train_df = pd.DataFrame(encoded_stage_fear_train, columns = stage_fear.get_feature_names_out(['Stage_fear']), index = train.index)
sf_test_df = pd.DataFrame(encoded_stage_fear_test, columns = stage_fear.get_feature_names_out(['Stage_fear']), index = test.index)
das_train_df = pd.DataFrame(encoded_drained_train, columns = drained_after_socializing.get_feature_names_out(['Drained_after_socializing']), index = train.index)
das_test_df = pd.DataFrame(encoded_drained_test, columns = drained_after_socializing.get_feature_names_out(['Drained_after_socializing']), index = test.index)

# %%
train['Personality'] = train['Personality'].apply(lambda x: 0 if x == 'Introvert' else 1)

# %%
train.head()
# Out:
#    id  Time_spent_Alone Stage_fear  Social_event_attendance  Going_outside  \
# 0   0               0.0         No                      6.0            4.0
# 1   1               1.0         No                      7.0            3.0
# 2   2               6.0        Yes                      1.0            0.0
# 3   3               3.0         No                      7.0            3.0
# 4   4               1.0         No                      4.0            4.0
#
#   Drained_after_socializing  Friends_circle_size  Post_frequency  Personality
# 0                        No                 15.0             5.0            1
# 1                        No                 10.0             8.0            1
# 2                   Unknown                  3.0             0.0            0
# 3                        No                 11.0             5.0            1
# 4                        No                 13.0             5.0            1

# %%
Final_train_set = pd.concat([train, sf_train_df, das_train_df],axis=1)

# %%
Final_train_set_X = Final_train_set.drop(dropping_columns, axis=1).copy()

# %%
Final_train_set_y = Final_train_set['Personality'].copy()

# %%
dropping_columns
# Out:
# ['id', 'Stage_fear', 'Drained_after_socializing', 'Personality']

# %%
Final_test = test.drop(['id', 'Stage_fear', 'Drained_after_socializing'],axis=1).copy()

# %%
Final_test
# Out:
#       Time_spent_Alone  Social_event_attendance  Going_outside  \
# 0                  3.0                      7.0            4.0
# 1                  2.0                      0.0            0.0
# 2                  3.0                      5.0            6.0
# 3                  3.0                      4.0            4.0
# 4                  9.0                      1.0            2.0
# ...                ...                      ...            ...
# 6170               3.0                      5.0            5.0
# 6171               8.0                      2.0            1.0
# 6172               2.0                      4.0            3.0
# 6173               3.0                      4.0            4.0
# 6174               2.0                      1.0            1.0
#
#       Friends_circle_size  Post_frequency
# 0                     6.0             5.0
# 1                     5.0             1.0
# 2                    15.0             9.0
# ...

# %%
Final_test = pd.concat([Final_test, sf_test_df, das_test_df],axis=1)

# %%
xgb = XGBClassifier(random_state =42)

xgb.fit(Final_train_set_X,Final_train_set_y)
pred_xgb = xgb.predict(Final_test)

# %%
pred_xgb
# Out:
# array([1, 0, 1, ..., 1, 1, 0], shape=(6175,))

# %%
pred_xgb_df = pd.DataFrame(pred_xgb, columns = ['Personality'], index = test.index)

# %%
final_submission = pd.concat([test['id'], pred_xgb_df],axis =1 )

# %%
final_submission['Personality'] = final_submission['Personality'].apply(lambda x: 'Introvert' if x == 0 else 'Extrovert')

# %%
final_submission.to_csv('final_subbmission.csv', index = False)

# %%
final_submission
# Out:
#          id Personality
# 0     18524   Extrovert
# 1     18525   Introvert
# 2     18526   Extrovert
# 3     18527   Extrovert
# 4     18528   Introvert
# ...     ...         ...
# 6170  24694   Extrovert
# 6171  24695   Introvert
# 6172  24696   Extrovert
# 6173  24697   Extrovert
# 6174  24698   Introvert
#
# [6175 rows x 2 columns]

# %%
param_grid = {
    'n_estimators': [100, 200, 300],
    'max_depth': [3, 5, 7],
    'learning_rate': [0.01, 0.05, 0.1],
    'subsample': [0.8, 1.0],
    'colsample_bytree': [0.8, 1.0]
}

# %%
from xgboost import XGBClassifier
from sklearn.model_selection import GridSearchCV

xgb = XGBClassifier(random_state=42, use_label_encoder=False, eval_metric='logloss')

grid = GridSearchCV(
    estimator=xgb,
    param_grid=param_grid,
    scoring='accuracy',
    cv=5,
    n_jobs=-1,
    verbose=1
)

grid.fit(Final_train_set_X,Final_train_set_y)

print("Best Parameters:", grid.best_params_)
print("Best CV Accuracy:", grid.best_score_)
# Out:
# Fitting 5 folds for each of 108 candidates, totalling 540 fits
# C:\Users\kumar\anaconda3\envs\learning_phase\Lib\site-packages\xgboost\training.py:183: UserWarning: [18:15:56] WARNING: D:\bld\xgboost-split_1748292851775\work\src\learner.cc:738:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# Best Parameters: {'colsample_bytree': 0.8, 'learning_rate': 0.05, 'max_depth': 3, 'n_estimators': 200, 'subsample': 0.8}
# Best CV Accuracy: 0.9693373615131033

# %% [markdown]
# Well lets see what we can do with these params

# %%
# Rebuild and fit the best model
best_xgb = XGBClassifier(
    colsample_bytree=0.8,
    learning_rate=0.05,
    max_depth=7,
    n_estimators=100,
    subsample=0.8,
    random_state=42,
    use_label_encoder=False,
    eval_metric='logloss'
)

best_xgb.fit(Final_train_set_X, Final_train_set_y)
final_preds_xgb = best_xgb.predict(Final_test)
# Out:
# C:\Users\kumar\anaconda3\envs\learning_phase\Lib\site-packages\xgboost\training.py:183: UserWarning: [18:15:56] WARNING: D:\bld\xgboost-split_1748292851775\work\src\learner.cc:738:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)

# %%
final_preds_xgb
# Out:
# array([1, 0, 1, ..., 1, 1, 0], shape=(6175,))

# %%
final_submission = pd.DataFrame(final_preds_xgb, columns = ['Personality'], index = test.index)

# %%
final_submission = pd.concat([test['id'],final_submission],axis=1)

# %%
final_submission['Personality'] = final_submission['Personality'].apply(lambda x: 'Introvert' if x == 0 else 'Extrovert')

# %%
final_submission.to_csv('final_subbmission.csv', index = False)

# %%
from sklearn.ensemble import VotingClassifier
from sklearn.model_selection import cross_val_score

voting = VotingClassifier(
    estimators=[
        ('lr', LogisticRegression(max_iter=1000)),
        ('rf', RandomForestClassifier(n_estimators=300, random_state=42)),
        ('xgb', best_xgb)
    ],
    voting='soft',  # use 'hard' if models don't support predict_proba
    n_jobs=-1
)

# Cross-validation (same as you did before)
scores = cross_val_score(voting, Final_train_set_X, Final_train_set_y, cv=5, scoring='accuracy')

print("VotingClassifier CV Accuracy scores:", scores)
print("Mean Voting Accuracy:", scores.mean())
# Out:
# VotingClassifier CV Accuracy scores: [0.96869096 0.97139001 0.96491228 0.96680162 0.97354212]
# Mean Voting Accuracy: 0.9690673976851082

# %%
voting.fit(Final_train_set_X, Final_train_set_y)
# Out:
# VotingClassifier(estimators=[('lr', LogisticRegression(max_iter=1000)),
#                              ('rf',
#                               RandomForestClassifier(n_estimators=300,
#                                                      random_state=42)),
#                              ('xgb',
#                               XGBClassifier(base_score=None, booster=None,
#                                             callbacks=None,
#                                             colsample_bylevel=None,
#                                             colsample_bynode=None,
#                                             colsample_bytree=0.8, device=None,
#                                             early_stopping_rounds=None,
#                                             enable_categorical=False,
#                                             eval_metric='logloss'...
#                                             grow_policy=None,
# ...

# %%
pred_voting = voting.predict(Final_test)

# %%
from xgboost import XGBClassifier
from sklearn.model_selection import RandomizedSearchCV

param_dist = {
    'n_estimators': [200, 300, 400, 500],
    'max_depth': [4, 5, 6, 7],
    'learning_rate': [0.01, 0.025, 0.05],
    'subsample': [0.7, 0.8, 0.9],
    'colsample_bytree': [0.7, 0.8, 0.9],
    'gamma': [0, 0.1, 0.2, 0.3],
    'reg_alpha': [0, 0.1, 1],
    'reg_lambda': [1, 1.5, 2],
    'min_child_weight': [1, 3, 5, 10]
}

# %%
xgb2 = XGBClassifier(
    random_state=42,
    eval_metric='logloss',
    use_label_encoder=False  # Optional: remove if warning is annoying
)

# %%
search = RandomizedSearchCV(
    estimator=xgb,
    param_distributions=param_dist,
    n_iter=40,              # 40 diverse tries — good balance
    scoring='accuracy',
    cv=5,
    verbose=1,
    n_jobs=-1
)

# %%
search.fit(Final_train_set_X, Final_train_set_y)
# Out:
# Fitting 5 folds for each of 40 candidates, totalling 200 fits
# C:\Users\kumar\anaconda3\envs\learning_phase\Lib\site-packages\xgboost\training.py:183: UserWarning: [18:18:13] WARNING: D:\bld\xgboost-split_1748292851775\work\src\learner.cc:738:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# RandomizedSearchCV(cv=5,
#                    estimator=XGBClassifier(base_score=None, booster=None,
#                                            callbacks=None,
#                                            colsample_bylevel=None,
#                                            colsample_bynode=None,
#                                            colsample_bytree=None, device=None,
#                                            early_stopping_rounds=None,
#                                            enable_categorical=False,
#                                            eval_metric='logloss',
# ...

# %%
best_xgb = search.best_estimator_

print("Best parameters:", search.best_params_)
print("Best CV accuracy:", search.best_score_)
# Out:
# Best parameters: {'subsample': 0.7, 'reg_lambda': 1.5, 'reg_alpha': 0, 'n_estimators': 400, 'min_child_weight': 1, 'max_depth': 6, 'learning_rate': 0.05, 'gamma': 0, 'colsample_bytree': 0.7}
# Best CV accuracy: 0.9691754181932651

# %%
from sklearn.model_selection import StratifiedKFold
import numpy as np
from xgboost.callback import EarlyStopping

skf = StratifiedKFold(n_splits=5, shuffle=True, random_state=42)
scores = []

for train_idx, val_idx in skf.split(Final_train_set_X, Final_train_set_y):
    X_tr, X_val = Final_train_set_X.iloc[train_idx], Final_train_set_X.iloc[val_idx]
    y_tr, y_val = Final_train_set_y[train_idx], Final_train_set_y[val_idx]

    model = XGBClassifier(
        colsample_bytree=0.8,
        learning_rate=0.03,
        max_depth=7,
        n_estimators=1000,
        subsample=0.8,
        random_state=42,
        eval_metric='logloss',
        early_stopping_rounds=25
    )

    model.fit(
        X_tr, y_tr,
        eval_set=[(X_val, y_val)],
        verbose=False
    )

    preds = model.predict(X_val)
    acc = accuracy_score(y_val, preds)
    scores.append(acc)

print("Early-stopped CV Accuracy scores:", scores)
print("Mean:", np.mean(scores))
# Out:
# Early-stopped CV Accuracy scores: [0.9697705802968961, 0.9676113360323887, 0.9662618083670715, 0.9700404858299595, 0.9713822894168467]
# Mean: 0.9690132999886323

# %%
from sklearn.ensemble import StackingClassifier
from sklearn.linear_model import LogisticRegression
from sklearn.ensemble import RandomForestClassifier
from xgboost import XGBClassifier
from sklearn.model_selection import cross_val_score

# Define base models
log_clf = LogisticRegression(random_state=42, max_iter=1000)
rf_clf = RandomForestClassifier(n_estimators=150, random_state=42)
xgb_clf = XGBClassifier(
    colsample_bytree=0.8,
    learning_rate=0.03,
    max_depth=7,
    n_estimators=1000,
    subsample=0.8,
    random_state=42,
    eval_metric='logloss'
)

# Meta-model: logistic regression (can also be XGBClassifier)
meta_model = LogisticRegression(random_state=42, max_iter=1000)

# Build stacking classifier
stacking_clf = StackingClassifier(
    estimators=[
        ('lr', log_clf),
        ('rf', rf_clf),
        ('xgb', xgb_clf)
    ],
    final_estimator=meta_model,
    passthrough=True,  # Pass original features along with predictions
    n_jobs=-1
)

# Evaluate using cross-validation
scores = cross_val_score(stacking_clf, Final_train_set_X, Final_train_set_y, cv=5, scoring='accuracy')
print("StackingClassifier CV scores:", scores)
print("Mean Accuracy:", scores.mean())
# Out:
# StackingClassifier CV scores: [0.96923077 0.97112011 0.96491228 0.96680162 0.97300216]
# Mean Accuracy: 0.9690133874310298

# %%
Final_train_set
# Out:
#           id  Time_spent_Alone Stage_fear  Social_event_attendance  \
# 0          0               0.0         No                      6.0
# 1          1               1.0         No                      7.0
# 2          2               6.0        Yes                      1.0
# 3          3               3.0         No                      7.0
# 4          4               1.0         No                      4.0
# ...      ...               ...        ...                      ...
# 18519  18519               3.0         No                      7.0
# 18520  18520               1.0    Unknown                      6.0
# 18521  18521               7.0        Yes                      1.0
# 18522  18522               2.0        Yes                      1.0
# 18523  18523               1.0         No                      8.0
#
#        Going_outside Drained_after_socializing  Friends_circle_size  \
# 0                4.0                        No                 15.0
# ...

# %% [markdown]
# drained_after_socializing_unknown and stage_fear_unknown we are going to drop them and then retrain

# %%
dfs_train_X = Final_train_set_X.drop(['Drained_after_socializing_Unknown','Stage_fear_Unknown'], axis=1).copy()

# %%
scores = cross_val_score(best_xgb,Final_train_set_X,Final_train_set_y,cv=5, scoring = 'accuracy')
print(f'Cross Validation Scores: {scores}')
print(f'Mean Accuracy: {scores.mean()}')
# Out:
# C:\Users\kumar\anaconda3\envs\learning_phase\Lib\site-packages\xgboost\training.py:183: UserWarning: [19:41:46] WARNING: D:\bld\xgboost-split_1748292851775\work\src\learner.cc:738:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# C:\Users\kumar\anaconda3\envs\learning_phase\Lib\site-packages\xgboost\training.py:183: UserWarning: [19:41:48] WARNING: D:\bld\xgboost-split_1748292851775\work\src\learner.cc:738:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# C:\Users\kumar\anaconda3\envs\learning_phase\Lib\site-packages\xgboost\training.py:183: UserWarning: [19:41:51] WARNING: D:\bld\xgboost-split_1748292851775\work\src\learner.cc:738:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# ...

# %%
trial_xgb = XGBClassifier(
    colsample_bytree = 0.8, 
    learning_rate = 0.05, 
    max_depth = 3, 
    n_estimators = 200, 
    subsample = 0.8,
    random_state = 42,
    eval_metrics = 'logloss'
)

# %%
scores = cross_val_score(trial_xgb,Final_train_set_X,Final_train_set_y,cv=5, scoring = 'accuracy')
# Out:
# C:\Users\kumar\anaconda3\envs\learning_phase\Lib\site-packages\xgboost\training.py:183: UserWarning: [19:47:24] WARNING: D:\bld\xgboost-split_1748292851775\work\src\learner.cc:738:
# Parameters: { "eval_metrics" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# C:\Users\kumar\anaconda3\envs\learning_phase\Lib\site-packages\xgboost\training.py:183: UserWarning: [19:47:25] WARNING: D:\bld\xgboost-split_1748292851775\work\src\learner.cc:738:
# Parameters: { "eval_metrics" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# C:\Users\kumar\anaconda3\envs\learning_phase\Lib\site-packages\xgboost\training.py:183: UserWarning: [19:47:26] WARNING: D:\bld\xgboost-split_1748292851775\work\src\learner.cc:738:
# Parameters: { "eval_metrics" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# ...

# %%
print(f'Cross Validation Scores: {scores} \nMean Accuracy: {scores.mean()}')
# Out:
# Cross Validation Scores: [0.96896086 0.97112011 0.96491228 0.96707152 0.97462203]
# Mean Accuracy: 0.9693373615131033

# %%
trial_xgb.fit(Final_train_set_X, Final_train_set_y)
# Out:
# C:\Users\kumar\anaconda3\envs\learning_phase\Lib\site-packages\xgboost\training.py:183: UserWarning: [19:50:28] WARNING: D:\bld\xgboost-split_1748292851775\work\src\learner.cc:738:
# Parameters: { "eval_metrics" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# XGBClassifier(base_score=None, booster=None, callbacks=None,
#               colsample_bylevel=None, colsample_bynode=None,
#               colsample_bytree=0.8, device=None, early_stopping_rounds=None,
#               enable_categorical=False, eval_metric=None,
#               eval_metrics='logloss', feature_types=None, feature_weights=None,
#               gamma=None, grow_policy=None, importance_type=None,
#               interaction_constraints=None, learning_rate=0.05, max_bin=None,
#               max_cat_threshold=None, max_cat_to_onehot=None,
#               max_delta_step=None, max_depth=3, max_leaves=None,
#               min_child_weight=None, missing=nan, monotone_constraints=None,
# ...

# %%
pred_tria_xgb = trial_xgb.predict(Final_test)

# %%
pred_trial_df = pd.DataFrame(pred_tria_xgb, columns = ['Personality'], index = test.index)

# %%
pred_trial_df['Personality'] = pred_trial_df['Personality'].apply(lambda x: 'Introvert' if x ==0 else 'Extrovert')

# %%
pred_trial_df
# Out:
#      Personality
# 0      Extrovert
# 1      Introvert
# 2      Extrovert
# 3      Extrovert
# 4      Introvert
# ...          ...
# 6170   Extrovert
# 6171   Introvert
# 6172   Extrovert
# 6173   Extrovert
# 6174   Introvert
#
# [6175 rows x 1 columns]

# %%
final_submit3 = pd.concat([test['id'], pred_trial_df], axis = 1)

# %%
final_submit3.to_csv('final_submit_3.csv', index = False)

# %%
import optuna
from sklearn.model_selection import cross_val_score
from xgboost import XGBClassifier

def objective(trial):
    params = {
        'n_estimators': trial.suggest_int('n_estimators', 100, 1000),
        'max_depth': trial.suggest_int('max_depth', 3, 10),
        'learning_rate': trial.suggest_float('learning_rate', 0.01, 0.3, log=True),
        'subsample': trial.suggest_float('subsample', 0.5, 1.0),
        'colsample_bytree': trial.suggest_float('colsample_bytree', 0.5, 1.0),
        'gamma': trial.suggest_float('gamma', 0, 5),
        'reg_alpha': trial.suggest_float('reg_alpha', 0, 5),
        'reg_lambda': trial.suggest_float('reg_lambda', 0, 5),
        'eval_metric': 'logloss',
        'random_state': 42,
        'use_label_encoder': False
    }

    model = XGBClassifier(**params)
    score = cross_val_score(model, Final_train_set_X, Final_train_set_y, cv=5, scoring='accuracy', n_jobs=-1)
    return score.mean()

study = optuna.create_study(direction='maximize')
study.optimize(objective, n_trials=50)  # you can increase for better tuning

print("Best Hyperparameters:", study.best_params)
print("Best Accuracy:", study.best_value)
# Out:
# [I 2025-07-07 20:24:31,034] A new study created in memory with name: no-name-3f31007a-5d76-4d3d-807d-38470e66fdbc
# [I 2025-07-07 20:24:42,760] Trial 0 finished with value: 0.9691753890457994 and parameters: {'n_estimators': 689, 'max_depth': 3, 'learning_rate': 0.07904524154005903, 'subsample': 0.5227322981637985, 'colsample_bytree': 0.588812681986119, 'gamma': 2.1026265816387406, 'reg_alpha': 2.321425092319933, 'reg_lambda': 3.367711799435676}. Best is trial 0 with value: 0.9691753890457994.
# [I 2025-07-07 20:24:51,878] Trial 1 finished with value: 0.96906745598004 and parameters: {'n_estimators': 524, 'max_depth': 7, 'learning_rate': 0.08069235247634178, 'subsample': 0.6109063533584362, 'colsample_bytree': 0.8798841013892904, 'gamma': 2.8627279020074967, 'reg_alpha': 1.8227081603842827, 'reg_lambda': 4.61299203471092}. Best is trial 0 with value: 0.9691753890457994.
# ...

# %%
best_params = study.best_params

# %%
tuned_xgb = XGBClassifier(**best_params)

# %%
tuned_xgb.fit(Final_train_set_X,Final_train_set_y)
# Out:
# XGBClassifier(base_score=None, booster=None, callbacks=None,
#               colsample_bylevel=None, colsample_bynode=None,
#               colsample_bytree=0.5011167720437688, device=None,
#               early_stopping_rounds=None, enable_categorical=False,
#               eval_metric=None, feature_types=None, feature_weights=None,
#               gamma=0.9063279741360379, grow_policy=None, importance_type=None,
#               interaction_constraints=None, learning_rate=0.03889084532205898,
#               max_bin=None, max_cat_threshold=None, max_cat_to_onehot=None,
#               max_delta_step=None, max_depth=6, max_leaves=None,
#               min_child_weight=None, missing=nan, monotone_constraints=None,
#               multi_strategy=None, n_estimators=851, n_jobs=None,
#               num_parallel_tree=None, ...)

# %%
pred_final4 = tuned_xgb.predict(Final_test)

# %%
final_submit4 = pd.DataFrame(pred_final4, columns = ['Personality'], index=test.index)

# %%
final_submit4 = pd.concat([test['id'], final_submit4], axis =1)

# %%
final_submit4['Personality'] = final_submit4['Personality'].apply(lambda x:'Introvert' if x == 0 else 'Extrovert')

# %%
final_submit4.to_csv('final_submit_4.csv', index=False)

# %%
from sklearn.ensemble import RandomForestClassifier

def objective_rf(trial):
    params = {
        'n_estimators': trial.suggest_int('n_estimators', 100, 500),
        'max_depth': trial.suggest_int('max_depth', 3, 20),
        'min_samples_split': trial.suggest_int('min_samples_split', 2, 10),
        'min_samples_leaf': trial.suggest_int('min_samples_leaf', 1, 10),
        'max_features': trial.suggest_categorical('max_features', ['sqrt', 'log2', None]),
        'bootstrap': trial.suggest_categorical('bootstrap', [True, False]),
        'random_state': 42
    }

    model = RandomForestClassifier(**params)
    score = cross_val_score(model, Final_train_set_X, Final_train_set_y, cv=5, scoring='accuracy', n_jobs=-1)
    return score.mean()

study_rf = optuna.create_study(direction='maximize')
study_rf.optimize(objective_rf, n_trials=50)

print("Best RF params:", study_rf.best_params)
print("Best RF accuracy:", study_rf.best_value)
# Out:
# [I 2025-07-07 20:42:57,116] A new study created in memory with name: no-name-81373176-b892-4ef7-aad7-d30d56409d2d
# [I 2025-07-07 20:43:06,388] Trial 0 finished with value: 0.9688514732586576 and parameters: {'n_estimators': 133, 'max_depth': 8, 'min_samples_split': 9, 'min_samples_leaf': 1, 'max_features': 'sqrt', 'bootstrap': False}. Best is trial 0 with value: 0.9688514732586576.
# [I 2025-07-07 20:43:09,686] Trial 1 finished with value: 0.9689054543652702 and parameters: {'n_estimators': 123, 'max_depth': 17, 'min_samples_split': 7, 'min_samples_leaf': 2, 'max_features': 'sqrt', 'bootstrap': True}. Best is trial 1 with value: 0.9689054543652702.
# [I 2025-07-07 20:43:11,935] Trial 2 finished with value: 0.9687974921520448 and parameters: {'n_estimators': 103, 'max_depth': 13, 'min_samples_split': 2, 'min_samples_leaf': 9, 'max_features': 'log2', 'bootstrap': True}. Best is trial 1 with value: 0.9689054543652702.
# ...

# %%
from sklearn.linear_model import LogisticRegression

def objective_lr(trial):
    params = {
        'C': trial.suggest_float('C', 0.001, 10, log=True),
        'penalty': trial.suggest_categorical('penalty', ['l1', 'l2', 'elasticnet']),
        'solver': trial.suggest_categorical('solver', ['saga']),
        'l1_ratio': trial.suggest_float('l1_ratio', 0.0, 1.0) if 'elasticnet' in trial.params.get('penalty', '') else None,
        'max_iter': 1000,
        'random_state': 42
    }

    # Filter out None values that sklearn won't accept
    filtered_params = {k: v for k, v in params.items() if v is not None}

    model = LogisticRegression(**filtered_params)
    score = cross_val_score(model, Final_train_set_X, Final_train_set_y, cv=5, scoring='accuracy', n_jobs=-1)
    return score.mean()

study_lr = optuna.create_study(direction='maximize')
study_lr.optimize(objective_lr, n_trials=50)

print("Best LR params:", study_lr.best_params)
print("Best LR accuracy:", study_lr.best_value)
# Out:
# [I 2025-07-07 20:54:07,932] A new study created in memory with name: no-name-97c4630d-c796-4170-af88-c0432701a67a
# [I 2025-07-07 20:54:16,734] Trial 0 finished with value: 0.9680417566594673 and parameters: {'C': 0.0011168391194319117, 'penalty': 'l2', 'solver': 'saga'}. Best is trial 0 with value: 0.9680417566594673.
# [I 2025-07-07 20:54:23,996] Trial 1 finished with value: 0.96895942089815 and parameters: {'C': 7.606250844846443, 'penalty': 'l1', 'solver': 'saga'}. Best is trial 1 with value: 0.96895942089815.
# [I 2025-07-07 20:54:31,015] Trial 2 finished with value: 0.966044295403736 and parameters: {'C': 0.0013518341142541538, 'penalty': 'elasticnet', 'solver': 'saga', 'l1_ratio': 0.9313074292027904}. Best is trial 1 with value: 0.96895942089815.
# [I 2025-07-07 20:54:40,092] Trial 3 finished with value: 0.9690134165784956 and parameters: {'C': 0.3854547398432767, 'penalty': 'l1', 'solver': 'saga'}. Best is trial 3 with value: 0.9690134165784956.
# ...

# %%
params_lr = study_lr.best_params

# %%
lr_best = LogisticRegression(**params_lr)

# %%
lr_best.fit(Final_train_set_X, Final_train_set_y)
# Out:
# LogisticRegression(C=0.022347014532377873, l1_ratio=0.05654328514065465,
#                    penalty='elasticnet', solver='saga')

# %%
pred_lr = lr_best.predict(Final_test)

# %%
final_submit_5 = pd.DataFrame(pred_lr,columns=['Personality'],index=test.index)

# %%
final_submit_5['Personality'] = final_submit_5['Personality'].apply(lambda x : 'Introvert' if x == 0 else 'Extrovert')

# %%
pd.concat([test['id'],final_submit_5],axis=1).to_csv('final_submit_5.csv', index =False)
